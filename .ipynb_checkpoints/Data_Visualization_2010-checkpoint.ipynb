# %%
# Imports - these are all the imports needed for the assignment
# %matplotlib inline
from scipy import stats
import numpy.ma as ma
from scipy.stats import kstest, normaltest

import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1a) Load the nba csv files

# YOUR CODE HERE
df_2010 = pd.read_csv('clean_players_2010.csv')

# %%
df_2010
# Out:
#      Unnamed: 0  PLAYER_ID          PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0             0     201985             AJ Price  1610612754               IND
# 1             1     201166         Aaron Brooks  1610612756               PHX
# 2             2     201189           Aaron Gray  1610612740               NOH
# 3             3     201151             Acie Law  1610612744               GSW
# 4             4       1733        Al Harrington  1610612743               DEN
# 5             5     201143           Al Horford  1610612737               ATL
# 6             6       2744         Al Jefferson  1610612762               UTA
# 7             7     201154          Al Thornton  1610612744               GSW
# 8             8     202329      Al-Farouq Aminu  1610612746               LAC
# 9             9     201582        Alexis Ajinca  1610612761               TOR
# 10           10     202087           Alonzo Gee  1610612739               CLE
# 11           11       2405    Amar'e Stoudemire  1610612752               NYK
# 12           12     101161         Amir Johnson  1610612761               TOR
# 13           13       2760     Anderson Varejao  1610612739               CLE
# 14           14     101154       Andray Blatche  1610612764               WAS
# 15           15       2738       Andre Iguodala  1610612755               PHI
# 16           16       1889         Andre Miller  1610612757               POR
# 17           17     200745      Andrea Bargnani  1610612761               TOR
# 18           18       1905     Andrei Kirilenko  1610612762               UTA
# 19           19       2804       Andres Nocioni  1610612755               PHI
# 20           20     101106         Andrew Bogut  1610612749               MIL
# 21           21     101115         Andrew Bynum  1610612747               LAL
# 22           22       2740      Andris Biedrins  1610612744               GSW
# 23           24       1712       Antawn Jamison  1610612739               CLE
# 24           25       1853       Anthony Carter  1610612752               NYK
# 25           26     201627       Anthony Morrow  1610612751               NJN
# 26           27       1515       Anthony Parker  1610612739               CLE
# 27           28     201576     Anthony Randolph  1610612750               MIN
# 28           29     201229     Anthony Tolliver  1610612750               MIN
# 29           32        686      Antonio McDyess  1610612759               SAS
# ..          ...        ...                  ...         ...               ...
# 392         421       1499          Tony Battie  1610612755               PHI
# 393         422       2225          Tony Parker  1610612759               SAS
# 394         423       1503        Tracy McGrady  1610612765               DET
# 395         424       2566        Travis Outlaw  1610612751               NJN
# 396         425       2772         Trevor Ariza  1610612740               NOH
# 397         426     202344        Trevor Booker  1610612764               WAS
# 398         427     201234         Trey Johnson  1610612747               LAL
# 399         428       2211          Troy Murphy  1610612738               BOS
# 400         429     201951            Ty Lawson  1610612743               DEN
# 401         430     201946     Tyler Hansbrough  1610612754               IND
# 402         431     201936         Tyreke Evans  1610612758               SAC
# 403         432     200748         Tyrus Thomas  1610612766               CHA
# 404         433       2199       Tyson Chandler  1610612742               DAL
# 405         434       2617        Udonis Haslem  1610612748               MIA
# 406         435       1713         Vince Carter  1610612756               PHX
# 407         436       2209  Vladimir Radmanovic  1610612744               GSW
# 408         437     101144            Von Wafer  1610612738               BOS
# 409         438     201961      Wayne Ellington  1610612750               MIN
# 410         439     202325       Wesley Johnson  1610612750               MIN
# 411         440     202083      Wesley Matthews  1610612757               POR
# 412         441     101198           Will Bynum  1610612765               DET
# 413         442       2584         Willie Green  1610612740               NOH
# 414         443     202378        Willie Warren  1610612746               LAC
# 415         444     201163      Wilson Chandler  1610612743               DEN
# 416         445     202333         Xavier Henry  1610612763               MEM
# 417         447     201146          Yi Jianlian  1610612764               WAS
# 418         448     202220       Zabian Dowdell  1610612756               PHX
# 419         449       2216        Zach Randolph  1610612763               MEM
# 420         450       2585        Zaza Pachulia  1610612737               ATL
# 421         451        980   Zydrunas Ilgauskas  1610612748               MIA
#
#       AGE  GP   W   L  W_PCT        ...          BLKA_RANK  PF_RANK  PFD_RANK  \
# 0
#
#      PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0         240              162                   274       224        27
# 1         132              372                   179       154        27
# 2         362              145                   326       154        27
# 3         321              369                   335       224        27
# 4         137               94                   176       181        27
# 5          58              157                    25         9        27
# 6          28              340                    18         7        27
# 7         212              337                   259       224        27
# 8         257              350                   270       224        27
# 9         322              178                   329       224        27
# 10        252              435                   265       224        27
# 11          6              144                     4        25        27
# 12        161              309                   112        57        27
# 13        171              445                    77        83        27
# 14         42              421                    34        42        27
# 15         71               68                    31        57         2
# 16         95               53                    65        57        27
# 17         16              434                    51       154        27
# 18        111              221                    78       111        27
# 19        249              368                   282       154        27
# 20         93              180                    22        28        27
# 21        118               37                    64        42        27
# 22        291              422                   163       129        27
# 23         33              451                    53        62        27
# 24        357              175                   314       224        27
# 25         87              336                   171       224        27
# 26        189              428                   175       224        27
# 27        206              407                   218       102        27
# 28        235              272                   216       129        27
# 29        275               91                   222       102        27
# ..        ...              ...                   ...       ...       ...
# 392       376              247                   361       224        27
# 393        35               33                    50        67        27
# 394       197              273                   154       129        27
# 395       167              429                   194       224        27
# 396       127              187                   101       129        27
# 397       277              371                   255       102        27
# 398       319              361                   362       224        27
# 399       364              414                   340       224        27
# 400       114               62                   120       111        27
# 401       129              310                   165        83        27
# 402        34              409                    30        93        27
# 403       143              219                   121       111        27
# 404       146               31                    99        39        27
# 405       195               28                   161       111        27
# 406        74               98                   111       154        27
# 407       286              150                   266       224        27
# 408       360              189                   391       224        27
# 409       236              399                   293       224        27
# 410       173              376                   178       224        27
# 411        50               89                   103       181        27
# 412       200              378                   223       224        27
# 413       178              244                   251       224        27
# 414       406              123                   402       224        27
# 415        59               69                    70        93        27
# 416       314              270                   373       224        27
# 417       259              408                   264       129        27
# 418       288              330                   299       224        27
# 419        21               46                    17         4        27
# 420       306              307                   281       111        27
# 421       290               61                   263       129        27
#
#      CFID           CFPARAMS
# 0       5  201985,1610612754
# 1       5  201166,1610612756
# 2       5  201189,1610612740
# 3       5  201151,1610612744
# 4       5    1733,1610612743
# 5       5  201143,1610612737
# 6       5    2744,1610612762
# 7       5  201154,1610612744
# 8       5  202329,1610612746
# 9       5  201582,1610612761
# 10      5  202087,1610612739
# 11      5    2405,1610612752
# 12      5  101161,1610612761
# 13      5    2760,1610612739
# 14      5  101154,1610612764
# 15      5    2738,1610612755
# 16      5    1889,1610612757
# 17      5  200745,1610612761
# 18      5    1905,1610612762
# 19      5    2804,1610612755
# 20      5  101106,1610612749
# 21      5  101115,1610612747
# 22      5    2740,1610612744
# 23      5    1712,1610612739
# 24      5    1853,1610612752
# 25      5  201627,1610612751
# 26      5    1515,1610612739
# 27      5  201576,1610612750
# 28      5  201229,1610612750
# 29      5     686,1610612759
# ..    ...                ...
# 392     5    1499,1610612755
# 393     5    2225,1610612759
# 394     5    1503,1610612765
# 395     5    2566,1610612751
# 396     5    2772,1610612740
# 397     5  202344,1610612764
# 398     5  201234,1610612747
# 399     5    2211,1610612738
# 400     5  201951,1610612743
# 401     5  201946,1610612754
# 402     5  201936,1610612758
# 403     5  200748,1610612766
# 404     5    2199,1610612742
# 405     5    2617,1610612748
# 406     5    1713,1610612756
# 407     5    2209,1610612744
# 408     5  101144,1610612738
# 409     5  201961,1610612750
# 410     5  202325,1610612750
# 411     5  202083,1610612757
# 412     5  101198,1610612765
# 413     5    2584,1610612740
# 414     5  202378,1610612746
# 415     5  201163,1610612743
# 416     5  202333,1610612763
# 417     5  201146,1610612764
# 418     5  202220,1610612756
# 419     5    2216,1610612763
# 420     5    2585,1610612737
# 421     5     980,1610612748
#
# [422 rows x 66 columns]

# %%
df_2010['PTS'].plot.hist(bins=40)

# %%
df_2010.columns[1:]
#pts_2016 = df_2016.as_matrix(columns=df_2016.columns[27:])
#x = pts_2016 #The array needs to be larger than 20, just an example
#mx = ma.masked_array(x)
#z,pval = mstats.normaltest(mx)

#if(pval < 0.055)\l,[]
#   print("Not normal distribution")
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK',
#        'TD3_RANK', 'CFID', 'CFPARAMS'],
#       dtype='object')

# %%
z,pval = stats.normaltest(df_2010['PTS'])
print(z, pval)
if(pval < 0.05):
    print('PTS Is not from a Normal Dist')
else:
    print('PTS Is likley from a Normal Dist')

size = df_2010['PTS'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2010['PTS'])
stat, kpval = kstest(df_2010['PTS'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Gamma Dist')
else:
    print('PTS Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2010['PTS'])
stat, kpval = kstest(df_2010['PTS'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Log norm Dist')
else:
    print('PTS Is likley from a Log norm Dist')
# Out:
# 49.0319459993 2.25345146046e-11
# PTS Is not from a Normal Dist
# 0.0402352095073 0.49669357931
# PTS Is likley from a Gamma Dist
# 0.0411791560522 0.465200024851
# PTS Is likley from a Log norm Dist

# %%
df_2010['BLK'].plot.hist(bins=10)

# %%
z,pval = stats.normaltest(df_2010['BLK'])
print(z, pval)
if(pval < 0.05):
    print('BLK Is not from a Normal Dist')
else:
    print('BLK Is likley from a Normal Dist')
    
size = df_2010['BLK'].size
x = scipy.arange(size)
param = stats.expon.fit(df_2010['BLK'])
stat, kpval = kstest(df_2010['BLK'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Exponen Dist')
else:
    print('BLK Is likley from a Exponen Dist')
param = stats.gamma.fit(df_2010['BLK'])
stat, kpval = kstest(df_2010['BLK'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Gamma Dist')
else:
    print('BLK Is likley from a Gamma Dist')
param = stats.lognorm.fit(df_2010['BLK'])
stat, kpval = kstest(df_2010['BLK'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Log norm Dist')
else:
    print('BLK Is likley from a Log norm Dist')
param = stats.chi2.fit(df_2010['BLK'])
stat, kpval = kstest(df_2010['BLK'], 'chi2', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Chisq Dist')
else:
    print('BLK Is likley from a Chisq Dist')
# Out:
# 178.778606784 1.5091026985e-39
# BLK Is not from a Normal Dist
# 0.121070362176 7.55466527047e-06
# BLK Is not from a Exponen Dist
# 0.19136191777 5.21804821574e-14
# BLK Is not from a Gamma Dist
# 0.0985720091106 0.000507058024288
# BLK Is not from a Log norm Dist
# 0.146944514616 2.03855088365e-08
# BLK Is not from a Chisq Dist

# %%
df_2010['STL'].plot.hist(bins=15)

# %%
z,pval = stats.normaltest(df_2010['STL'])
print(z, pval)
if(pval < 0.05):
    print('STL Is not from a Normal Dist')
else:
    print('STL Is likley from a Normal Dist')
    
size = df_2010['STL'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2010['STL'])
stat, kpval = kstest(df_2010['STL'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Gamma Dist')
else:
    print('STL Is likley from a Gamma Dist')

param = stats.expon.fit(df_2010['STL'])
stat, kpval = kstest(df_2010['STL'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Exponen Dist')
else:
    print('STL Is likley from a Exponen Dist')

param = stats.lognorm.fit(df_2010['STL'])
stat, kpval = kstest(df_2010['STL'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Log norm Dist')
else:
    print('STL Is likley from a Log norm Dist')
# Out:
# 66.2945158191 4.02095117504e-15
# STL Is not from a Normal Dist
# 0.0694113871146 0.032655420565
# STL Is not from a Gamma Dist
# 0.239811750729 0.0
# STL Is not from a Exponen Dist
# 0.0741231597352 0.018375990381
# STL Is not from a Log norm Dist

# %%
df_2010['TOV'].plot.hist(bins=12)

# %%
z,pval = stats.normaltest(df_2010['TOV'])
print(z, pval)
if(pval < 0.05):
    print('TOV Is not from a Normal Dist')
else:
    print('TOV Is likley from a Normal Dist')
    
size = df_2010['TOV'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2010['TOV'])
stat, kpval = kstest(df_2010['TOV'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Gamma Dist')
else:
    print('TOV Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2010['TOV'])
stat, kpval = kstest(df_2010['TOV'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Log norm Dist')
else:
    print('TOV Is likley from a Log norm Dist')
# Out:
# 72.063989382 2.24648505492e-16
# TOV Is not from a Normal Dist
# 0.0538904791582 0.166256231529
# TOV Is likley from a Gamma Dist
# 0.0423248860683 0.42877592054
# TOV Is likley from a Log norm Dist

# %%
df_2010['AST'].plot.hist(bins=20)

# %%
z,pval = stats.normaltest(df_2010['AST'])
print(z, pval)
if(pval < 0.05):
    print('AST Is not from a Normal Dist')
else:
    print('AST Is likley from a Normal Dist')

size = df_2010['AST'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2010['AST'])
stat, kpval = kstest(df_2010['AST'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Gamma Dist')
else:
    print('AST Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2010['AST'])
stat, kpval = kstest(df_2010['AST'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Log norm Dist')
else:
    print('AST Is likley from a Log norm Dist')
# Out:
# 204.665292019 3.60991120594e-45
# AST Is not from a Normal Dist
# 0.0504905977861 0.224871491055
# AST Is likley from a Gamma Dist
# 0.043550602932 0.39199592006
# AST Is likley from a Log norm Dist

# %%
df_2010['REB'].plot.hist(bins=25)

# %%
z,pval = stats.normaltest(df_2010['REB'])
print(z, pval)
if(pval < 0.05):
    print('REB Is not from a Normal Dist')
else:
    print('REB Is likley from a Normal Dist')
    
size = df_2010['REB'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2010['REB'])
stat, kpval = kstest(df_2010['REB'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Gamma Dist')
else:
    print('REB Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2010['REB'])
stat, kpval = kstest(df_2010['REB'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Log norm Dist')
else:
    print('REB Is likley from a Log norm Dist')
# Out:
# 109.193696837 1.94486742581e-24
# REB Is not from a Normal Dist
# 0.0403778470735 0.491848869709
# REB Is likley from a Gamma Dist
# 0.0265545148301 0.927264468069
# REB Is likley from a Log norm Dist
