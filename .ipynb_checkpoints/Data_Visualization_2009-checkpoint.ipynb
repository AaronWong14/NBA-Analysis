# 396     5  201936,1610612758
# 397     5  200748,1610612766
# 398     5    2199,1610612766
# 399     5    2617,1610612748
# 400     5    1713,1610612753
# 401     5    2209,1610612744
# 402     5  201961,1610612750
# 403     5  202083,1610612762
# 404     5  101198,1610612765
# 405     5    2584,1610612755
# 406     5  201163,1610612752
# 407     5  201146,1610612751
# 408     5    2216,1610612763
# 409     5    2585,1610612737
# 410     5     980,1610612739
#
# [411 rows x 66 columns]

# %%
df_2009['PTS'].plot.hist(bins=40)

# %%
df_2009.columns[1:]
#pts_2016 = df_2016.as_matrix(columns=df_2016.columns[27:])
#x = pts_2016 #The array needs to be larger than 20, just an example
#mx = ma.masked_array(x)
#z,pval = mstats.normaltest(mx)

#if(pval < 0.055):
#   print("Not normal distribution")
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK',
#        'TD3_RANK', 'CFID', 'CFPARAMS'],
#       dtype='object')

# %%
z,pval = stats.normaltest(df_2009['PTS'])
print(z, pval)
if(pval < 0.05):
    print('PTS Is not from a Normal Dist')
else:
    print('PTS Is likley from a Normal Dist')

size = df_2009['PTS'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2009['PTS'])
stat, kpval = kstest(df_2009['PTS'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Gamma Dist')
else:
    print('PTS Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2009['PTS'])
stat, kpval = kstest(df_2009['PTS'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Log norm Dist')
else:
    print('PTS Is likley from a Log norm Dist')
# Out:
# 48.8378173353 2.48314860893e-11
# PTS Is not from a Normal Dist
# 0.0373429367491 0.620170047811
# PTS Is likley from a Gamma Dist
# 0.0411217229623 0.484788279697
# PTS Is likley from a Log norm Dist

# %%
df_2009['BLK'].plot.hist(bins=10)

# %%
z,pval = stats.normaltest(df_2009['BLK'])
print(z, pval)
if(pval < 0.05):
    print('BLK Is not from a Normal Dist')
else:
    print('BLK Is likley from a Normal Dist')
    
size = df_2009['BLK'].size
x = scipy.arange(size)
param = stats.expon.fit(df_2009['BLK'])
stat, kpval = kstest(df_2009['BLK'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Exponen Dist')
else:
    print('BLK Is likley from a Exponen Dist')
param = stats.gamma.fit(df_2009['BLK'])
stat, kpval = kstest(df_2009['BLK'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Gamma Dist')
else:
    print('BLK Is likley from a Gamma Dist')
param = stats.lognorm.fit(df_2009['BLK'])
stat, kpval = kstest(df_2009['BLK'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Log norm Dist')
else:
    print('BLK Is likley from a Log norm Dist')
param = stats.chi2.fit(df_2009['BLK'])
stat, kpval = kstest(df_2009['BLK'], 'chi2', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Chisq Dist')
else:
    print('BLK Is likley from a Chisq Dist')
# Out:
# 154.506092304 2.81467558522e-34
# BLK Is not from a Normal Dist
# 0.128699576557 2.14692650924e-06
# BLK Is not from a Exponen Dist
# 0.248466775671 0.0
# BLK Is not from a Gamma Dist
# 0.110095109476 8.56273939767e-05
# BLK Is not from a Log norm Dist
# 0.156829325238 2.69861244462e-09
# BLK Is not from a Chisq Dist

# %%
df_2009['STL'].plot.hist(bins=15)

# %%
z,pval = stats.normaltest(df_2009['STL'])
print(z, pval)
if(pval < 0.05):
    print('STL Is not from a Normal Dist')
else:
    print('STL Is likley from a Normal Dist')
    
size = df_2009['STL'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2009['STL'])
stat, kpval = kstest(df_2009['STL'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Gamma Dist')
else:
    print('STL Is likley from a Gamma Dist')

param = stats.expon.fit(df_2009['STL'])
stat, kpval = kstest(df_2009['STL'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Exponen Dist')
else:
    print('STL Is likley from a Exponen Dist')

param = stats.lognorm.fit(df_2009['STL'])
stat, kpval = kstest(df_2009['STL'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Log norm Dist')
else:
    print('STL Is likley from a Log norm Dist')
# Out:
# 64.9028679878 8.063457228e-15
# STL Is not from a Normal Dist
# 0.0701206448661 0.0334537470825
# STL Is not from a Gamma Dist
# 0.24923387068 0.0
# STL Is not from a Exponen Dist
# 0.071708126374 0.0277632223221
# STL Is not from a Log norm Dist

# %%
df_2009['TOV'].plot.hist(bins=12)

# %%
z,pval = stats.normaltest(df_2009['TOV'])
print(z, pval)
if(pval < 0.05):
    print('TOV Is not from a Normal Dist')
else:
    print('TOV Is likley from a Normal Dist')
    
size = df_2009['TOV'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2009['TOV'])
stat, kpval = kstest(df_2009['TOV'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Gamma Dist')
else:
    print('TOV Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2009['TOV'])
stat, kpval = kstest(df_2009['TOV'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Log norm Dist')
else:
    print('TOV Is likley from a Log norm Dist')
# Out:
# 51.6098073093 6.20973027671e-12
# TOV Is not from a Normal Dist
# 0.0577252695287 0.12430864551
# TOV Is likley from a Gamma Dist
# 0.0539085433049 0.1769469263
# TOV Is likley from a Log norm Dist

# %%
df_2009['AST'].plot.hist(bins=20)

# %%
z,pval = stats.normaltest(df_2009['AST'])
print(z, pval)
if(pval < 0.05):
    print('AST Is not from a Normal Dist')
else:
    print('AST Is likley from a Normal Dist')

size = df_2009['AST'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2009['AST'])
stat, kpval = kstest(df_2009['AST'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Gamma Dist')
else:
    print('AST Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2009['AST'])
stat, kpval = kstest(df_2009['AST'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Log norm Dist')
else:
    print('AST Is likley from a Log norm Dist')
# Out:
# 182.140385399 2.81007456976e-40
# AST Is not from a Normal Dist
# 0.050521552448 0.237235507686
# AST Is likley from a Gamma Dist
# 0.0425314907678 0.439574997495
# AST Is likley from a Log norm Dist

# %%
df_2009['REB'].plot.hist(bins=25)

# %%
z,pval = stats.normaltest(df_2009['REB'])
print(z, pval)
if(pval < 0.05):
    print('REB Is not from a Normal Dist')
else:
    print('REB Is likley from a Normal Dist')
    
size = df_2009['REB'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2009['REB'])
stat, kpval = kstest(df_2009['REB'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Gamma Dist')
else:
    print('REB Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2009['REB'])
stat, kpval = kstest(df_2009['REB'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Log norm Dist')
else:
    print('REB Is likley from a Log norm Dist')
# Out:
# 78.7422523115 7.96777688203e-18
# REB Is not from a Normal Dist
# 0.0543167154687 0.170585714763
# REB Is likley from a Gamma Dist
# 0.0323343059812 0.783417162142
# REB Is likley from a Log norm Dist
