# %%
# Imports - these are all the imports needed for the assignment
# %matplotlib inline
from scipy import stats
import numpy.ma as ma
from scipy.stats import kstest, normaltest

import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1a) Load the nba csv files

# YOUR CODE HERE
df_2003 = pd.read_csv('clean_players_2003.csv')

# %%
df_2003
# Out:
#      Unnamed: 0  PLAYER_ID          PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0             0        243          Aaron McKie  1610612755               PHI
# 1             1       1425       Aaron Williams  1610612751               NJN
# 2             2       1502         Adonal Foyle  1610612744               GSW
# 3             3       1559       Adrian Griffin  1610612745               HOU
# 4             4       1733        Al Harrington  1610612754               IND
# 5             7        275        Allan Houston  1610612752               NYK
# 6             8        947        Allen Iverson  1610612755               PHI
# 7             9        297      Alonzo Mourning  1610612751               NJN
# 8            11       1541       Alvin Williams  1610612761               TOR
# 9            12       1043       Amal McCaskill  1610612755               PHI
# 10           13       2405    Amar'e Stoudemire  1610612756               PHX
# 11           14       1889         Andre Miller  1610612743               DEN
# 12           15       1905     Andrei Kirilenko  1610612762               UTA
# 13           16        692      Andrew DeClercq  1610612753               ORL
# 14           17        358    Anfernee Hardaway  1610612752               NYK
# 15           18       1738           Ansu Sesay  1610612760               SEA
# 16           19       1712       Antawn Jamison  1610612742               DAL
# 17           21        924     Anthony Goldwire  1610612751               NJN
# 18           22       1533      Anthony Johnson  1610612754               IND
# 19           23        324       Anthony Peeler  1610612758               SAC
# 20           24        952       Antoine Walker  1610612742               DAL
# 21           25       1498      Antonio Daniels  1610612760               SEA
# 22           26        213        Antonio Davis  1610612741               CHI
# 23           27        686      Antonio McDyess  1610612756               PHX
# 24           28       1506      Austin Croshere  1610612754               IND
# 25           29        422        Avery Johnson  1610612744               GSW
# 26           30       1884          Baron Davis  1610612740               NOH
# 27           31       1052       Ben Handlogten  1610612762               UTA
# 28           32       1112          Ben Wallace  1610612765               DET
# 29           33        902          Bimbo Coles  1610612748               MIA
# ..          ...        ...                  ...         ...               ...
# 368         409        145         Tracy Murray  1610612757               POR
# 369         410        696          Travis Best  1610612742               DAL
# 370         411       2580        Travis Hansen  1610612737               ATL
# 371         413       1762     Tremaine Fowlkes  1610612765               DET
# 372         414       2239      Trenton Hassell  1610612750               MIN
# 373         416       1607          Troy Hudson  1610612750               MIN
# 374         417       2211          Troy Murphy  1610612744               GSW
# 375         419       1731           Tyronn Lue  1610612753               ORL
# 376         420       2199       Tyson Chandler  1610612741               CHI
# 377         421       2617        Udonis Haslem  1610612748               MIA
# 378         422        452            Vin Baker  1610612752               NYK
# 379         423       1713         Vince Carter  1610612761               TOR
# 380         424        958     Vitaly Potapenko  1610612760               SEA
# 381         425        124          Vlade Divac  1610612758               SAC
# 382         426       2209  Vladimir Radmanovic  1610612760               SEA
# 383         427       1735    Vladimir Stepania  1610612757               POR
# 384         428        702        Voshon Lenard  1610612743               DEN
# 385         429       1887     Wally Szczerbiak  1610612750               MIN
# 386         430        962       Walter McCarty  1610612738               BOS
# 387         431       1917         Wang Zhi-zhi  1610612748               MIA
# 388         432        445        Wesley Person  1610612737               ATL
# 389         433       2584         Willie Green  1610612755               PHI
# 390         434       2397             Yao Ming  1610612745               HOU
# 391         435       2216        Zach Randolph  1610612757               POR
# 392         436       2560      Zarko Cabarkapa  1610612756               PHX
# 393         437       2585        Zaza Pachulia  1610612753               ORL
# 394         438       1442       Zeljko Rebraca  1610612737               ATL
# 395         439       1985      Zendon Hamilton  1610612755               PHI
# 396         440       2565       Zoran Planinic  1610612751               NJN
# 397         441        980   Zydrunas Ilgauskas  1610612739               CLE
#
#       AGE  GP   W   L  W_PCT       ...         BLKA_RANK  PF_RANK  PFD_RANK  \
# 0
# 383     5  1735,1610612757
# 384     5   702,1610612743
# 385     5  1887,1610612750
# 386     5   962,1610612738
# 387     5  1917,1610612748
# 388     5   445,1610612737
# 389     5  2584,1610612755
# 390     5  2397,1610612745
# 391     5  2216,1610612757
# 392     5  2560,1610612756
# 393     5  2585,1610612753
# 394     5  1442,1610612737
# 395     5  1985,1610612755
# 396     5  2565,1610612751
# 397     5   980,1610612739
#
# [398 rows x 66 columns]

# %%
df_2003['PTS'].plot.hist(bins=40)

# %%
df_2003.columns[1:]
#pts_2016 = df_2016.as_matrix(columns=df_2016.columns[27:])
#x = pts_2016 #The array needs to be larger than 20, just an example
#mx = ma.masked_array(x)
#z,pval = mstats.normaltest(mx)

#if(pval < 0.055):
#   print("Not normal distribution")
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK',
#        'TD3_RANK', 'CFID', 'CFPARAMS'],
#       dtype='object')

# %%
z,pval = stats.normaltest(df_2003['PTS'])
print(z, pval)
if(pval < 0.05):
    print('PTS Is not from a Normal Dist')
else:
    print('PTS Is likley from a Normal Dist')

size = df_2003['PTS'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2003['PTS'])
stat, kpval = kstest(df_2003['PTS'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Gamma Dist')
else:
    print('PTS Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2003['PTS'])
stat, kpval = kstest(df_2003['PTS'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Log norm Dist')
else:
    print('PTS Is likley from a Log norm Dist')
# Out:
# 48.3604431541 3.15255881689e-11
# PTS Is not from a Normal Dist
# 0.0457095966804 0.367763104082
# PTS Is likley from a Gamma Dist
# 0.0459983026158 0.360021183568
# PTS Is likley from a Log norm Dist

# %%
df_2003['BLK'].plot.hist(bins=10)

# %%
z,pval = stats.normaltest(df_2003['BLK'])
print(z, pval)
if(pval < 0.05):
    print('BLK Is not from a Normal Dist')
else:
    print('BLK Is likley from a Normal Dist')
    
size = df_2003['BLK'].size
x = scipy.arange(size)
param = stats.expon.fit(df_2003['BLK'])
stat, kpval = kstest(df_2003['BLK'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Exponen Dist')
else:
    print('BLK Is likley from a Exponen Dist')
param = stats.gamma.fit(df_2003['BLK'])
stat, kpval = kstest(df_2003['BLK'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Gamma Dist')
else:
    print('BLK Is likley from a Gamma Dist')
param = stats.lognorm.fit(df_2003['BLK'])
stat, kpval = kstest(df_2003['BLK'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Log norm Dist')
else:
    print('BLK Is likley from a Log norm Dist')
param = stats.chi2.fit(df_2003['BLK'])
stat, kpval = kstest(df_2003['BLK'], 'chi2', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Chisq Dist')
else:
    print('BLK Is likley from a Chisq Dist')
# Out:
# 225.749515415 9.53049771276e-50
# BLK Is not from a Normal Dist
# 0.125330145809 6.58278407895e-06
# BLK Is not from a Exponen Dist
# 0.206037198871 2.6645352591e-15
# BLK Is not from a Gamma Dist
# 0.113414463415 6.47303638981e-05
# BLK Is not from a Log norm Dist
# 0.456822248185 0.0
# BLK Is not from a Chisq Dist

# %%
df_2003['STL'].plot.hist(bins=15)

# %%
z,pval = stats.normaltest(df_2003['STL'])
print(z, pval)
if(pval < 0.05):
    print('STL Is not from a Normal Dist')
else:
    print('STL Is likley from a Normal Dist')
    
size = df_2003['STL'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2003['STL'])
stat, kpval = kstest(df_2003['STL'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Gamma Dist')
else:
    print('STL Is likley from a Gamma Dist')

param = stats.expon.fit(df_2003['STL'])
stat, kpval = kstest(df_2003['STL'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Exponen Dist')
else:
    print('STL Is likley from a Exponen Dist')

param = stats.lognorm.fit(df_2003['STL'])
stat, kpval = kstest(df_2003['STL'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Log norm Dist')
else:
    print('STL Is likley from a Log norm Dist')
# Out:
# 49.2666620744 2.00391944587e-11
# STL Is not from a Normal Dist
# 0.0748744893083 0.0218742250701
# STL Is not from a Gamma Dist
# 0.229786414847 0.0
# STL Is not from a Exponen Dist
# 0.0787823684432 0.0135139401716
# STL Is not from a Log norm Dist

# %%
df_2003['TOV'].plot.hist(bins=12)

# %%
z,pval = stats.normaltest(df_2003['TOV'])
print(z, pval)
if(pval < 0.05):
    print('TOV Is not from a Normal Dist')
else:
    print('TOV Is likley from a Normal Dist')
    
size = df_2003['TOV'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2003['TOV'])
stat, kpval = kstest(df_2003['TOV'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Gamma Dist')
else:
    print('TOV Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2003['TOV'])
stat, kpval = kstest(df_2003['TOV'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Log norm Dist')
else:
    print('TOV Is likley from a Log norm Dist')
# Out:
# 52.7746747811 3.46836647061e-12
# TOV Is not from a Normal Dist
# 0.0608293949416 0.100903451913
# TOV Is likley from a Gamma Dist
# 0.0658958292656 0.0602846190948
# TOV Is likley from a Log norm Dist

# %%
df_2003['AST'].plot.hist(bins=20)

# %%
z,pval = stats.normaltest(df_2003['AST'])
print(z, pval)
if(pval < 0.05):
    print('AST Is not from a Normal Dist')
else:
    print('AST Is likley from a Normal Dist')

size = df_2003['AST'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2003['AST'])
stat, kpval = kstest(df_2003['AST'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Gamma Dist')
else:
    print('AST Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2003['AST'])
stat, kpval = kstest(df_2003['AST'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Log norm Dist')
else:
    print('AST Is likley from a Log norm Dist')
# Out:
# 113.22910701 2.58590054279e-25
# AST Is not from a Normal Dist
# 0.0662164889688 0.0582704245694
# AST Is likley from a Gamma Dist
# 0.0485003433098 0.297735082831
# AST Is likley from a Log norm Dist

# %%
df_2003['REB'].plot.hist(bins=25)

# %%
z,pval = stats.normaltest(df_2003['REB'])
print(z, pval)
if(pval < 0.05):
    print('REB Is not from a Normal Dist')
else:
    print('REB Is likley from a Normal Dist')
    
size = df_2003['REB'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2003['REB'])
stat, kpval = kstest(df_2003['REB'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Gamma Dist')
else:
    print('REB Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2003['REB'])
stat, kpval = kstest(df_2003['REB'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Log norm Dist')
else:
    print('REB Is likley from a Log norm Dist')
# Out:
# 78.7992141557 7.74404836971e-18
# REB Is not from a Normal Dist
# 0.0335774825308 0.760628934041
# REB Is likley from a Gamma Dist
# 0.0408211698862 0.516721126092
# REB Is likley from a Log norm Dist
