# %%
# Imports - these are all the imports needed for the assignment
# %matplotlib inline
from scipy import stats
import numpy.ma as ma
from scipy.stats import kstest, normaltest

import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1a) Load the nba csv files

# YOUR CODE HERE
df_2014 = pd.read_csv('clean_players_2014.csv')

# %%
df_2014
# Out:
#      Unnamed: 0  PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0             0     201985           AJ Price  1610612739               CLE
# 1             1     201166       Aaron Brooks  1610612741               CHI
# 2             2     203932       Aaron Gordon  1610612753               ORL
# 3             3     203940      Adreian Payne  1610612750               MIN
# 4             4     201143         Al Horford  1610612737               ATL
# 5             5       2744       Al Jefferson  1610612766               CHA
# 6             6     202329    Al-Farouq Aminu  1610612742               DAL
# 7             7     101187      Alan Anderson  1610612751               BKN
# 8             8     202692         Alec Burks  1610612762               UTA
# 9            10     203458           Alex Len  1610612756               PHX
# 10           11     203144       Alexey Shved  1610612752               NYK
# 11           12     201582      Alexis Ajinca  1610612740               NOP
# 12           13     203459       Allen Crabbe  1610612757               POR
# 13           14     202087         Alonzo Gee  1610612757               POR
# 14           15       2405  Amar'e Stoudemire  1610612742               DAL
# 15           16     101161       Amir Johnson  1610612761               TOR
# 16           17       2760   Anderson Varejao  1610612739               CLE
# 17           19     203083     Andre Drummond  1610612765               DET
# 18           20       2738     Andre Iguodala  1610612744               GSW
# 19           21       1889       Andre Miller  1610612758               SAC
# 20           22     203460     Andre Roberson  1610612760               OKC
# 21           23     200745    Andrea Bargnani  1610612752               NYK
# 22           24       1905   Andrei Kirilenko  1610612751               BKN
# 23           25     101106       Andrew Bogut  1610612744               GSW
# 24           26     203094   Andrew Nicholson  1610612753               ORL
# 25           27     203952     Andrew Wiggins  1610612750               MIN
# 26           28     203461    Anthony Bennett  1610612750               MIN
# 27           29     203076      Anthony Davis  1610612740               NOP
# 28           30     201627     Anthony Morrow  1610612760               OKC
# 29           31     201229   Anthony Tolliver  1610612765               DET
# ..          ...        ...                ...         ...               ...
# 424         458     203100        Tony Wroten  1610612755               PHI
# 425         460     204037        Travis Wear  1610612752               NYK
# 426         461       2772       Trevor Ariza  1610612745               HOU
# 427         462     202344      Trevor Booker  1610612762               UTA
# 428         463     203504         Trey Burke  1610612762               UTA
# 429         464     202684   Tristan Thompson  1610612739               CLE
# 430         465     203584       Troy Daniels  1610612766               CHA
# 431         466     201951          Ty Lawson  1610612743               DEN
# 432         467     203898        Tyler Ennis  1610612749               MIL
# 433         468     201946   Tyler Hansbrough  1610612761               TOR
# 434         469     204020      Tyler Johnson  1610612748               MIA
# 435         470     203092       Tyler Zeller  1610612738               BOS
# 436         471     201936       Tyreke Evans  1610612740               NOP
# 437         473       2199     Tyson Chandler  1610612742               DAL
# 438         474       2617      Udonis Haslem  1610612748               MIA
# 439         476     201964      Victor Claver  1610612757               POR
# 440         477     203506     Victor Oladipo  1610612753               ORL
# 441         478       1713       Vince Carter  1610612763               MEM
# 442         479     201961    Wayne Ellington  1610612747               LAL
# 443         480     202325     Wesley Johnson  1610612747               LAL
# 444         481     202083    Wesley Matthews  1610612757               POR
# 445         482     203115        Will Barton  1610612743               DEN
# 446         483     101198         Will Bynum  1610612764               WAS
# 447         484     203805        Will Cherry  1610612761               TOR
# 448         485       2584       Willie Green  1610612753               ORL
# 449         486     201163    Wilson Chandler  1610612743               DEN
# 450         487     202333       Xavier Henry  1610612747               LAL
# 451         488     203897        Zach LaVine  1610612750               MIN
# 452         489       2216      Zach Randolph  1610612763               MEM
# 453         490       2585      Zaza Pachulia  1610612749               MIL
#
#       AGE  GP   W   L  W_PCT        ...          BLKA_RANK  PF_RANK  PFD_RANK  \
# 0
#
#      PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0         321              385                   371       252        21
# 1         124               70                   179       193        21
# 2         317              428                   306       193        21
# 3         254              486                   245       122        21
# 4          64               35                    36        46        13
# 5          40              341                    31        23        21
# 6         298              108                   217       104        21
# 7         230              270                   273       252        21
# 8          79              465                   110       152        21
# 9         268              235                   176        62        21
# 10        142              417                   197       152        21
# 11        258              216                   247        91        21
# 12        400              249                   394       252        21
# 13        344              345                   379       252        21
# 14        127              286                   145       104        21
# 15        173              142                   144        79        21
# 16        163              189                   135       152        21
# 17         80              264                    17         2        21
# 18        214               16                   178       252        21
# 19        347              331                   317       193        21
# 20        394              102                   305       193        21
# 21         66              490                   109       152        21
# 22        485              440                   477       252        21
# 23        262                8                    97        79        21
# 24        328              365                   380       252        21
# 25         37              481                    77       152        21
# 26        312              468                   300       152        21
# 27          5               34                     2         6        21
# 28        136               49                   212       152        21
# 29        260              113                   314       193        21
# ..        ...              ...                   ...       ...       ...
# 424        38              487                    58       152        21
# 425       373              332                   387       252        21
# 426        92               64                    82       122        21
# 427       239              170                   218       122        21
# 428        91              259                   108       122        21
# 429       196               68                   151        46        21
# 430       377              344                   437       252        21
# 431        63              236                    29        17        21
# 432       381              351                   378       252        21
# 433       385               69                   364       152        21
# 434       281              356                   275       193        21
# 435       148              318                   158       122        21
# 436        41               88                    30        31        13
# 437       144               56                    61        14        21
# 438       360              392                   334       122        21
# 439       429               86                   440       252        21
# 440        26              450                    51       122        21
# 441       288              167                   318       252        21
# 442       156              353                   214       193        21
# 443       160              446                   165       122        21
# 444        51               25                    87       252        21
# 445       249              250                   261       152        21
# 446       402              485                   397       252        21
# 447       451              277                   422       252        21
# 448       284              334                   349       252        21
# 449        76              403                    94        69        21
# 450       434              100                   458       252        21
# 451       151              484                   189       104        21
# 452        48               23                    44        10        21
# 453       202               42                   132        40        21
#
#      CFID           CFPARAMS
# 0       5  201985,1610612739
# 1       5  201166,1610612741
# 2       5  203932,1610612753
# 3       5  203940,1610612750
# 4       5  201143,1610612737
# 5       5    2744,1610612766
# 6       5  202329,1610612742
# 7       5  101187,1610612751
# 8       5  202692,1610612762
# 9       5  203458,1610612756
# 10      5  203144,1610612752
# 11      5  201582,1610612740
# 12      5  203459,1610612757
# 13      5  202087,1610612757
# 14      5    2405,1610612742
# 15      5  101161,1610612761
# 16      5    2760,1610612739
# 17      5  203083,1610612765
# 18      5    2738,1610612744
# 19      5    1889,1610612758
# 20      5  203460,1610612760
# 21      5  200745,1610612752
# 22      5    1905,1610612751
# 23      5  101106,1610612744
# 24      5  203094,1610612753
# 25      5  203952,1610612750
# 26      5  203461,1610612750
# 27      5  203076,1610612740
# 28      5  201627,1610612760
# 29      5  201229,1610612765
# ..    ...                ...
# 424     5  203100,1610612755
# 425     5  204037,1610612752
# 426     5    2772,1610612745
# 427     5  202344,1610612762
# 428     5  203504,1610612762
# 429     5  202684,1610612739
# 430     5  203584,1610612766
# 431     5  201951,1610612743
# 432     5  203898,1610612749
# 433     5  201946,1610612761
# 434     5  204020,1610612748
# 435     5  203092,1610612738
# 436     5  201936,1610612740
# 437     5    2199,1610612742
# 438     5    2617,1610612748
# 439     5  201964,1610612757
# 440     5  203506,1610612753
# 441     5    1713,1610612763
# 442     5  201961,1610612747
# 443     5  202325,1610612747
# 444     5  202083,1610612757
# 445     5  203115,1610612743
# 446     5  101198,1610612764
# 447     5  203805,1610612761
# 448     5    2584,1610612753
# 449     5  201163,1610612743
# 450     5  202333,1610612747
# 451     5  203897,1610612750
# 452     5    2216,1610612763
# 453     5    2585,1610612749
#
# [454 rows x 66 columns]

# %%
df_2014['PTS'].plot.hist(bins=40)

# %%
df_2014.columns[1:]
#pts_2016 = df_2016.as_matrix(columns=df_2016.columns[27:])
#x = pts_2016 #The array needs to be larger than 20, just an example
#mx = ma.masked_array(x)
#z,pval = mstats.normaltest(mx)

#if(pval < 0.055):
#   print("Not normal distribution")
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK',
#        'TD3_RANK', 'CFID', 'CFPARAMS'],
#       dtype='object')

# %%
z,pval = stats.normaltest(df_2014['PTS'])
print(z, pval)
if(pval < 0.05):
    print('PTS Is not from a Normal Dist')
else:
    print('PTS Is likley from a Normal Dist')

size = df_2014['PTS'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2014['PTS'])
stat, kpval = kstest(df_2014['PTS'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Gamma Dist')
else:
    print('PTS Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2014['PTS'])
stat, kpval = kstest(df_2014['PTS'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Log norm Dist')
else:
    print('PTS Is likley from a Log norm Dist')
# Out:
# 58.6862540891 1.80485302947e-13
# PTS Is not from a Normal Dist
# 0.0386301079798 0.502885767222
# PTS Is likley from a Gamma Dist
# 0.0503871707495 0.192833935739
# PTS Is likley from a Log norm Dist

# %%
df_2014['BLK'].plot.hist(bins=10)

# %%
z,pval = stats.normaltest(df_2014['BLK'])
print(z, pval)
if(pval < 0.05):
    print('BLK Is not from a Normal Dist')
else:
    print('BLK Is likley from a Normal Dist')
    
size = df_2014['BLK'].size
x = scipy.arange(size)
param = stats.expon.fit(df_2014['BLK'])
stat, kpval = kstest(df_2014['BLK'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Exponen Dist')
else:
    print('BLK Is likley from a Exponen Dist')
param = stats.gamma.fit(df_2014['BLK'])
stat, kpval = kstest(df_2014['BLK'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Gamma Dist')
else:
    print('BLK Is likley from a Gamma Dist')
param = stats.lognorm.fit(df_2014['BLK'])
stat, kpval = kstest(df_2014['BLK'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Log norm Dist')
else:
    print('BLK Is likley from a Log norm Dist')
param = stats.chi2.fit(df_2014['BLK'])
stat, kpval = kstest(df_2014['BLK'], 'chi2', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Chisq Dist')
else:
    print('BLK Is likley from a Chisq Dist')
# Out:
# 221.310083107 8.77255416895e-49
# BLK Is not from a Normal Dist
# 0.10792948045 4.63875848724e-05
# BLK Is not from a Exponen Dist
# 0.210788606173 0.0
# BLK Is not from a Gamma Dist
# 0.121477054815 2.69279540643e-06
# BLK Is not from a Log norm Dist
# 0.130972257973 2.99116527769e-07
# BLK Is not from a Chisq Dist

# %%
df_2014['STL'].plot.hist(bins=15)

# %%
z,pval = stats.normaltest(df_2014['STL'])
print(z, pval)
if(pval < 0.05):
    print('STL Is not from a Normal Dist')
else:
    print('STL Is likley from a Normal Dist')
    
size = df_2014['STL'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2014['STL'])
stat, kpval = kstest(df_2014['STL'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Gamma Dist')
else:
    print('STL Is likley from a Gamma Dist')

param = stats.expon.fit(df_2014['STL'])
stat, kpval = kstest(df_2014['STL'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Exponen Dist')
else:
    print('STL Is likley from a Exponen Dist')

param = stats.lognorm.fit(df_2014['STL'])
stat, kpval = kstest(df_2014['STL'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Log norm Dist')
else:
    print('STL Is likley from a Log norm Dist')
# Out:
# 73.8380900387 9.25257195008e-17
# STL Is not from a Normal Dist
# 0.0716127429861 0.0180561498826
# STL Is not from a Gamma Dist
# 0.235885906884 0.0
# STL Is not from a Exponen Dist
# 0.0704251868466 0.0210670591448
# STL Is not from a Log norm Dist

# %%
df_2014['TOV'].plot.hist(bins=12)

# %%
z,pval = stats.normaltest(df_2014['TOV'])
print(z, pval)
if(pval < 0.05):
    print('TOV Is not from a Normal Dist')
else:
    print('TOV Is likley from a Normal Dist')
    
size = df_2014['TOV'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2014['TOV'])
stat, kpval = kstest(df_2014['TOV'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Gamma Dist')
else:
    print('TOV Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2014['TOV'])
stat, kpval = kstest(df_2014['TOV'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Log norm Dist')
else:
    print('TOV Is likley from a Log norm Dist')
# Out:
# 110.737453233 8.98809306096e-25
# TOV Is not from a Normal Dist
# 0.0543191912356 0.132303414651
# TOV Is likley from a Gamma Dist
# 0.0511807068106 0.179122203277
# TOV Is likley from a Log norm Dist

# %%
df_2014['AST'].plot.hist(bins=20)

# %%
z,pval = stats.normaltest(df_2014['AST'])
print(z, pval)
if(pval < 0.05):
    print('AST Is not from a Normal Dist')
else:
    print('AST Is likley from a Normal Dist')

size = df_2014['AST'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2014['AST'])
stat, kpval = kstest(df_2014['AST'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Gamma Dist')
else:
    print('AST Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2014['AST'])
stat, kpval = kstest(df_2014['AST'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Log norm Dist')
else:
    print('AST Is likley from a Log norm Dist')
# Out:
# 176.092347684 5.78139373752e-39
# AST Is not from a Normal Dist
# 0.0563696260935 0.107497467403
# AST Is likley from a Gamma Dist
# 0.0392674582602 0.480510408125
# AST Is likley from a Log norm Dist

# %%
df_2014['REB'].plot.hist(bins=25)

# %%
z,pval = stats.normaltest(df_2014['REB'])
print(z, pval)
if(pval < 0.05):
    print('REB Is not from a Normal Dist')
else:
    print('REB Is likley from a Normal Dist')
    
size = df_2014['REB'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2014['REB'])
stat, kpval = kstest(df_2014['REB'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Gamma Dist')
else:
    print('REB Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2014['REB'])
stat, kpval = kstest(df_2014['REB'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Log norm Dist')
else:
    print('REB Is likley from a Log norm Dist')
# Out:
# 108.084020748 3.38729564387e-24
# REB Is not from a Normal Dist
# 0.0385681080615 0.505097317285
# REB Is likley from a Gamma Dist
# 0.0349560777385 0.644405224736
# REB Is likley from a Log norm Dist
