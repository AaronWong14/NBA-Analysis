# %%
# Imports - these are all the imports needed for the assignment
# %matplotlib inline
from scipy import stats
import numpy.ma as ma
from scipy.stats import kstest, normaltest

import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1a) Load the nba csv files

# YOUR CODE HERE
df_2012 = pd.read_csv('clean_players_2012.csv')

# %%
df_2012
# Out:
#      Unnamed: 0  PLAYER_ID          PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0             0     201985             AJ Price  1610612764               WAS
# 1             1     201166         Aaron Brooks  1610612745               HOU
# 2             2     201189           Aaron Gray  1610612761               TOR
# 3             3       1733        Al Harrington  1610612753               ORL
# 4             4     201143           Al Horford  1610612737               ATL
# 5             5       2744         Al Jefferson  1610612762               UTA
# 6             6     202329      Al-Farouq Aminu  1610612740               NOH
# 7             7     101187        Alan Anderson  1610612761               TOR
# 8             8     202692           Alec Burks  1610612762               UTA
# 9             9     203144         Alexey Shved  1610612750               MIN
# 10           10     202087           Alonzo Gee  1610612739               CLE
# 11           11       2405    Amar'e Stoudemire  1610612752               NYK
# 12           12     101161         Amir Johnson  1610612761               TOR
# 13           13       2760     Anderson Varejao  1610612739               CLE
# 14           14     101154       Andray Blatche  1610612751               BKN
# 15           15     203083       Andre Drummond  1610612765               DET
# 16           16       2738       Andre Iguodala  1610612743               DEN
# 17           17       1889         Andre Miller  1610612743               DEN
# 18           18     200745      Andrea Bargnani  1610612761               TOR
# 19           19       1905     Andrei Kirilenko  1610612750               MIN
# 20           20     101106         Andrew Bogut  1610612744               GSW
# 21           22     203094     Andrew Nicholson  1610612753               ORL
# 22           23       2740      Andris Biedrins  1610612744               GSW
# 23           24       1712       Antawn Jamison  1610612747               LAL
# 24           25     203076        Anthony Davis  1610612740               NOH
# 25           26     201627       Anthony Morrow  1610612742               DAL
# 26           27     201576     Anthony Randolph  1610612743               DEN
# 27           28     201229     Anthony Tolliver  1610612737               ATL
# 28           29     203102      Arnett Moultrie  1610612755               PHI
# 29           30     203382          Aron Baynes  1610612759               SAS
# ..          ...        ...                  ...         ...               ...
# 402         436       2754           Tony Allen  1610612763               MEM
# 403         437       2225          Tony Parker  1610612759               SAS
# 404         438     203100          Tony Wroten  1610612763               MEM
# 405         440       2566        Travis Outlaw  1610612758               SAC
# 406         441       2772         Trevor Ariza  1610612764               WAS
# 407         442     202344        Trevor Booker  1610612764               WAS
# 408         443     202684     Tristan Thompson  1610612739               CLE
# 409         444       2211          Troy Murphy  1610612742               DAL
# 410         445     201951            Ty Lawson  1610612743               DEN
# 411         446     201946     Tyler Hansbrough  1610612754               IND
# 412         448     203092         Tyler Zeller  1610612739               CLE
# 413         449     201936         Tyreke Evans  1610612758               SAC
# 414         450     200748         Tyrus Thomas  1610612766               CHA
# 415         451     203116       Tyshawn Taylor  1610612751               BKN
# 416         452       2199       Tyson Chandler  1610612752               NYK
# 417         453       2617        Udonis Haslem  1610612748               MIA
# 418         454     203139  Viacheslav Kravtsov  1610612765               DET
# 419         455     201964        Victor Claver  1610612757               POR
# 420         456       1713         Vince Carter  1610612742               DAL
# 421         457       2209  Vladimir Radmanovic  1610612741               CHI
# 422         458     201961      Wayne Ellington  1610612739               CLE
# 423         459     202325       Wesley Johnson  1610612756               PHX
# 424         460     202083      Wesley Matthews  1610612757               POR
# 425         461     203115          Will Barton  1610612757               POR
# 426         462     101198           Will Bynum  1610612765               DET
# 425  22.0  73  27  46  0.370        ...                257      422       373
# 426  30.0  65  26  39  0.400        ...                 70      170       157
# 427  31.0  72  48  24  0.667        ...                343      323       415
# 428  26.0  43  33  10  0.767        ...                 87       39       136
# 429  22.0  50  16  34  0.320        ...                192      300       195
# 430  31.0  76  51  25  0.671        ...                 11       87        41
# 431  29.0  52  29  23  0.558        ...                 96       72       128
#
#      PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0         205              288                   216       173        27
# 1         222              441                   263       226        27
# 2         384              372                   370       173        27
# 3         294              434                   311       226        27
# 4          31               71                    17         6        27
# 5          24              366                    23         9        27
# 6         213              268                   124        69        27
# 7         133              299                   203       226        27
# 8         223              101                   265       226        27
# 9         183              268                   187       145        27
# 10        149              449                   150       145        27
# 11         67              121                   127       226        27
# 12        153               62                    88        45        27
# 13         71              419                    10        42        27
# 14        147              196                   138        93        27
# 15        197              254                   108        73        27
# 16         91               23                    55        69        10
# 17        160               65                   122       116        27
# 18         99              423                   148       226        27
# 19        102              214                    70        93        27
# 20        263              116                   111       173        27
# 21        203              370                   248       145        27
# 22        460              314                   384       226        27
# 23        165              161                   196       110        27
# 24         81              391                    50        29        27
# 25        338              308                   405       226        27
# 26        353              167                   346       173        27
# 27        328              275                   359       226        27
# 28        351              352                   349       173        27
# 29        392              187                   406       226        27
# ..        ...              ...                   ...       ...       ...
# 402       173               59                   140       145        27
# 403        11                6                    30        40        10
# 404       398              334                   415       226        27
# 405       287              265                   351       226        27
# 406       162              250                   137       145        27
# 407       282              425                   234       125        27
# 408       111              411                    80        16        27
# 409       312              313                   275       226        27
# 410        38               35                    46        73        27
# 411       225              185                   250       102        27
# 412       199              432                   174        93        27
# 413        54              431                    67       173        27
# 414       306              436                   299       226        27
# 415       411              346                   434       226        27
# 416       142               39                    74        29        27
# 417       346               43                   280       173        27
# 418       374              257                   391       173        27
# 419       349              378                   342       226        27
# 420        82               55                   104       173        27
# 421       440              324                   428       226        27
# 422       200              163                   256       226        27
# 423       195              453                   258       226        27
# 424        57              301                   103       173        27
# 425       332              409                   360       173        27
# 426       157              396                   197       125        27
# 427       248              113                   316       226        27
# 428        90               32                   117       226        27
# 429       345              413                   390       226        27
# 430        52               36                    43         4        27
# 431       262              224                   198       116        27
#
#      CFID           CFPARAMS
# 0       5  201985,1610612764
# 1       5  201166,1610612745
# 2       5  201189,1610612761
# 3       5    1733,1610612753
# 4       5  201143,1610612737
# 5       5    2744,1610612762
# 6       5  202329,1610612740
# 7       5  101187,1610612761
# 8       5  202692,1610612762
# 9       5  203144,1610612750
# 10      5  202087,1610612739
# 11      5    2405,1610612752
# 12      5  101161,1610612761
# 13      5    2760,1610612739
# 14      5  101154,1610612751
# 15      5  203083,1610612765
# 16      5    2738,1610612743
# 17      5    1889,1610612743
# 18      5  200745,1610612761
# 19      5    1905,1610612750
# 20      5  101106,1610612744
# 21      5  203094,1610612753
# 22      5    2740,1610612744
# 23      5    1712,1610612747
# 24      5  203076,1610612740
# 25      5  201627,1610612742
# 26      5  201576,1610612743
# 27      5  201229,1610612737
# 28      5  203102,1610612755
# 29      5  203382,1610612759
# ..    ...                ...
# 402     5    2754,1610612763
# 403     5    2225,1610612759
# 404     5  203100,1610612763
# 405     5    2566,1610612758
# 406     5    2772,1610612764
# 407     5  202344,1610612764
# 408     5  202684,1610612739
# 409     5    2211,1610612742
# 410     5  201951,1610612743
# 411     5  201946,1610612754
# 412     5  203092,1610612739
# 413     5  201936,1610612758
# 414     5  200748,1610612766
# 415     5  203116,1610612751
# 416     5    2199,1610612752
# 417     5    2617,1610612748
# 418     5  203139,1610612765
# 419     5  201964,1610612757
# 420     5    1713,1610612742
# 421     5    2209,1610612741
# 422     5  201961,1610612739
# 423     5  202325,1610612756
# 424     5  202083,1610612757
# 425     5  203115,1610612757
# 426     5  101198,1610612765
# 427     5    2584,1610612746
# 428     5  201163,1610612743
# 429     5  202333,1610612740
# 430     5    2216,1610612763
# 431     5    2585,1610612737
#
# [432 rows x 66 columns]

# %%
df_2012['PTS'].plot.hist(bins=40)

# %%
df_2012.columns[1:]
#pts_2016 = df_2016.as_matrix(columns=df_2016.columns[27:])
#x = pts_2016 #The array needs to be larger than 20, just an example
#mx = ma.masked_array(x)
#z,pval = mstats.normaltest(mx)

#if(pval < 0.055):
#   print("Not normal distribution")
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK',
#        'TD3_RANK', 'CFID', 'CFPARAMS'],
#       dtype='object')

# %%
z,pval = stats.normaltest(df_2012['PTS'])
print(z, pval)
if(pval < 0.05):
    print('PTS Is not from a Normal Dist')
else:
    print('PTS Is likley from a Normal Dist')

size = df_2012['PTS'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2012['PTS'])
stat, kpval = kstest(df_2012['PTS'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Gamma Dist')
else:
    print('PTS Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2012['PTS'])
stat, kpval = kstest(df_2012['PTS'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Log norm Dist')
else:
    print('PTS Is likley from a Log norm Dist')
# Out:
# 51.9673685852 5.19313116893e-12
# PTS Is not from a Normal Dist
# 0.0435895555917 0.376283345581
# PTS Is likley from a Gamma Dist
# 0.056247401084 0.125131256738
# PTS Is likley from a Log norm Dist

# %%
df_2012['BLK'].plot.hist(bins=10)

# %%
z,pval = stats.normaltest(df_2012['BLK'])
print(z, pval)
if(pval < 0.05):
    print('BLK Is not from a Normal Dist')
else:
    print('BLK Is likley from a Normal Dist')
    
size = df_2012['BLK'].size
x = scipy.arange(size)
param = stats.expon.fit(df_2012['BLK'])
stat, kpval = kstest(df_2012['BLK'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Exponen Dist')
else:
    print('BLK Is likley from a Exponen Dist')
param = stats.gamma.fit(df_2012['BLK'])
stat, kpval = kstest(df_2012['BLK'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Gamma Dist')
else:
    print('BLK Is likley from a Gamma Dist')
param = stats.lognorm.fit(df_2012['BLK'])
stat, kpval = kstest(df_2012['BLK'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Log norm Dist')
else:
    print('BLK Is likley from a Log norm Dist')
param = stats.chi2.fit(df_2012['BLK'])
stat, kpval = kstest(df_2012['BLK'], 'chi2', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Chisq Dist')
else:
    print('BLK Is likley from a Chisq Dist')
# Out:
# 214.715171414 2.37242743127e-47
# BLK Is not from a Normal Dist
# 0.120861290111 5.88348787334e-06
# BLK Is not from a Exponen Dist
# 0.35851032471 0.0
# BLK Is not from a Gamma Dist
# 0.0957328762727 0.000674642484937
# BLK Is not from a Log norm Dist
# 0.107734712441 8.04396684386e-05
# BLK Is not from a Chisq Dist

# %%
df_2012['STL'].plot.hist(bins=15)

# %%
z,pval = stats.normaltest(df_2012['STL'])
print(z, pval)
if(pval < 0.05):
    print('STL Is not from a Normal Dist')
else:
    print('STL Is likley from a Normal Dist')
    
size = df_2012['STL'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2012['STL'])
stat, kpval = kstest(df_2012['STL'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Gamma Dist')
else:
    print('STL Is likley from a Gamma Dist')

param = stats.expon.fit(df_2012['STL'])
stat, kpval = kstest(df_2012['STL'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Exponen Dist')
else:
    print('STL Is likley from a Exponen Dist')

param = stats.lognorm.fit(df_2012['STL'])
stat, kpval = kstest(df_2012['STL'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Log norm Dist')
else:
    print('STL Is likley from a Log norm Dist')
# Out:
# 78.2827558336 1.00257196596e-17
# STL Is not from a Normal Dist
# 0.0776995261865 0.0102628899667
# STL Is not from a Gamma Dist
# 0.245511202294 0.0
# STL Is not from a Exponen Dist
# 0.0774715500567 0.010583729679
# STL Is not from a Log norm Dist

# %%
df_2012['TOV'].plot.hist(bins=12)

# %%
z,pval = stats.normaltest(df_2012['TOV'])
print(z, pval)
if(pval < 0.05):
    print('TOV Is not from a Normal Dist')
else:
    print('TOV Is likley from a Normal Dist')
    
size = df_2012['TOV'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2012['TOV'])
stat, kpval = kstest(df_2012['TOV'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Gamma Dist')
else:
    print('TOV Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2012['TOV'])
stat, kpval = kstest(df_2012['TOV'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Log norm Dist')
else:
    print('TOV Is likley from a Log norm Dist')
# Out:
# 69.3006121423 8.94464846635e-16
# TOV Is not from a Normal Dist
# 0.0611884276871 0.075505638891
# TOV Is likley from a Gamma Dist
# 0.0498639649599 0.225720725085
# TOV Is likley from a Log norm Dist

# %%
df_2012['AST'].plot.hist(bins=20)

# %%
z,pval = stats.normaltest(df_2012['AST'])
print(z, pval)
if(pval < 0.05):
    print('AST Is not from a Normal Dist')
else:
    print('AST Is likley from a Normal Dist')

size = df_2012['AST'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2012['AST'])
stat, kpval = kstest(df_2012['AST'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Gamma Dist')
else:
    print('AST Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2012['AST'])
stat, kpval = kstest(df_2012['AST'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Log norm Dist')
else:
    print('AST Is likley from a Log norm Dist')
# Out:
# 159.254989767 2.61949976832e-35
# AST Is not from a Normal Dist
# 0.0671974220983 0.0385807584904
# AST Is not from a Gamma Dist
# 0.0502211058425 0.218800022112
# AST Is likley from a Log norm Dist

# %%
df_2012['REB'].plot.hist(bins=25)

# %%
z,pval = stats.normaltest(df_2012['REB'])
print(z, pval)
if(pval < 0.05):
    print('REB Is not from a Normal Dist')
else:
    print('REB Is likley from a Normal Dist')
    
size = df_2012['REB'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2012['REB'])
stat, kpval = kstest(df_2012['REB'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Gamma Dist')
else:
    print('REB Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2012['REB'])
stat, kpval = kstest(df_2012['REB'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Log norm Dist')
else:
    print('REB Is likley from a Log norm Dist')
# Out:
# 106.783945791 6.4887462904e-24
# REB Is not from a Normal Dist
# 0.0570303106007 0.1158324775
# REB Is likley from a Gamma Dist
# 0.0411417397983 0.45089156813
# REB Is likley from a Log norm Dist
