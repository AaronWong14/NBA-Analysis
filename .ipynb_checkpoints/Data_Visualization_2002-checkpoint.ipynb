# %%
# Imports - these are all the imports needed for the assignment
# %matplotlib inline
from scipy import stats
import numpy.ma as ma
from scipy.stats import kstest, normaltest

import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1a) Load the nba csv files

# YOUR CODE HERE
df_2002 = pd.read_csv('clean_players_2002.csv')

# %%
df_2002
# Out:
#      Unnamed: 0  PLAYER_ID          PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0             1        243          Aaron McKie  1610612755               PHI
# 1             2       1425       Aaron Williams  1610612751               NJN
# 2             3       2492      Adam Harrington  1610612743               DEN
# 3             4       1502         Adonal Foyle  1610612744               GSW
# 4             5       1559       Adrian Griffin  1610612742               DAL
# 5             6       1733        Al Harrington  1610612754               IND
# 6             7        673       Alan Henderson  1610612737               ATL
# 7             8        275        Allan Houston  1610612752               NYK
# 8             9        947        Allen Iverson  1610612755               PHI
# 9            11       1541       Alvin Williams  1610612761               TOR
# 10           12       1043       Amal McCaskill  1610612737               ATL
# 11           13       2405    Amar'e Stoudemire  1610612756               PHX
# 12           14       1889         Andre Miller  1610612746               LAC
# 13           15       1905     Andrei Kirilenko  1610612762               UTA
# 14           16        692      Andrew DeClercq  1610612753               ORL
# 15           17        358    Anfernee Hardaway  1610612756               PHX
# 16           18       1738           Ansu Sesay  1610612760               SEA
# 17           19       1712       Antawn Jamison  1610612744               GSW
# 18           20       1853       Anthony Carter  1610612748               MIA
# 19           21        924     Anthony Goldwire  1610612764               WAS
# 20           22       1533      Anthony Johnson  1610612751               NJN
# 21           23        193        Anthony Mason  1610612749               MIL
# 22           24        324       Anthony Peeler  1610612750               MIN
# 23           25       2541    Antoine Rigaudeau  1610612742               DAL
# 24           26        952       Antoine Walker  1610612738               BOS
# 25           27       1498      Antonio Daniels  1610612757               POR
# 26           28        213        Antonio Davis  1610612761               TOR
# 27           30       1609             Art Long  1610612761               TOR
# 28           31        717      Arvydas Sabonis  1610612757               POR
# 29           32       1506      Austin Croshere  1610612754               IND
# ..          ...        ...                  ...         ...               ...
# 367         397        763      Tony Massenburg  1610612762               UTA
# 368         398       2225          Tony Parker  1610612759               SAS
# 369         399       1503        Tracy McGrady  1610612753               ORL
# 370         400        145         Tracy Murray  1610612747               LAL
# 371         401        696          Travis Best  1610612748               MIA
# 372         402        969        Travis Knight  1610612752               NYK
# 373         403       1762     Tremaine Fowlkes  1610612746               LAC
# 374         404       2239      Trenton Hassell  1610612741               CHI
# 375         405       1607          Troy Hudson  1610612750               MIN
# 376         406       2211          Troy Murphy  1610612744               GSW
# 377         407        238          Tyrone Hill  1610612755               PHI
# 378         408       1731           Tyronn Lue  1610612764               WAS
# 379         409       2199       Tyson Chandler  1610612741               CHI
# 380         410        452            Vin Baker  1610612738               BOS
# 381         411       1713         Vince Carter  1610612761               TOR
# 382         412       2428    Vincent Yarbrough  1610612743               DEN
# 383         413        958     Vitaly Potapenko  1610612760               SEA
# 384         414        124          Vlade Divac  1610612758               SAC
# 385         415       2209  Vladimir Radmanovic  1610612760               SEA
# 386         416       1735    Vladimir Stepania  1610612748               MIA
# 387         417        702        Voshon Lenard  1610612761               TOR
# 388         418       1887     Wally Szczerbiak  1610612750               MIN
# 389         419       1005        Walt Williams  1610612742               DAL
# 390         420        962       Walter McCarty  1610612738               BOS
# 391         421       1917         Wang Zhi-zhi  1610612746               LAC
# 392         422        445        Wesley Person  1610612763               MEM
# 393         423       2397             Yao Ming  1610612745               HOU
# 394         424       2216        Zach Randolph  1610612757               POR
# 395         425       1442       Zeljko Rebraca  1610612765               DET
# 396         427        980   Zydrunas Ilgauskas  1610612739               CLE
#
#       AGE  GP   W   L  W_PCT       ...         BLKA_RANK  PF_RANK  PFD_RANK  \
# 0
#
#      PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0         141               54                   113       169        26
# 1         213              139                   216       169        26
# 2         390              325                   401       226        26
# 3         243              127                   131       107        26
# 4         284               56                   232       226        26
# 5          89               79                   109        61        26
# 6         260              363                   243       136        26
# 7          11              217                    55       226        26
# 8           3               65                     8        82        26
# 9          78              385                    72       136        26
# 10        406              306                   378       226        26
# 11         73              180                    69        18        26
# 12         72              392                    56        48         8
# 13         91              113                    52       107        26
# 14        265              105                   247       169        26
# 15        106              154                   104        91         8
# 16        365              350                   365       226        26
# 17         13              294                    26        34        26
# 18        298              370                   229       136        26
# 19        386              375                   412       226        26
# 20        296              177                   317       226        26
# 21        180              355                   139        73        26
# 22        169              151                   162       226        26
# 23        391              421                   400       226        26
# 24         25              117                    19        36         5
# 25        311              219                   325       226        26
# 26         70              343                    54        40        26
# 27        357              352                   347       226        26
# 28        215               49                   172       169        26
# 29        248              148                   272       226        26
# ..        ...              ...                   ...       ...       ...
# 367       267              317                   303       169        26
# 368        58               13                    83       107        26
# 369         1               48                     2        32         8
# 370       372              309                   396       226        26
# 371       154              377                   180       226        26
# 372       377              207                   358       226        26
# 373       280               53                   287       226        26
# 374       294              420                   233       226        26
# 375        67               93                    96        82        26
# 376        95              303                    73         9        26
# 377       234              389                   163        79        26
# 378       148              263                   173       169        26
# 379       137              401                   120        43        26
# 380       245              314                   252       226        26
# 381        23              232                    27       136        26
# 382       191              376                   183       226        26
# 383       300              334                   307       226        26
# 384       118               10                    67        53        26
# 385       116               66                   147       120        26
# 386       233              342                   179        79        26
# 387        66              412                   107       136        26
# 388        42               47                    63       136        26
# 389       236               81                   240       169        26
# 390       217              261                   207       226        26
# 391       279              210                   333       226        26
# 392        99              238                   151       169        26
# 393        74               85                    50        16        26
# 394       151              285                   194       107        26
# 395       201              120                   257       226        26
# 396        45              411                    39        25        26
#
#      CFID         CFPARAMS
# 0       5   243,1610612755
# 1       5  1425,1610612751
# 2       5  2492,1610612743
# 3       5  1502,1610612744
# 4       5  1559,1610612742
# 5       5  1733,1610612754
# 6       5   673,1610612737
# 7       5   275,1610612752
# 8       5   947,1610612755
# 9       5  1541,1610612761
# 10      5  1043,1610612737
# 11      5  2405,1610612756
# 12      5  1889,1610612746
# 13      5  1905,1610612762
# 14      5   692,1610612753
# 15      5   358,1610612756
# 16      5  1738,1610612760
# 17      5  1712,1610612744
# 18      5  1853,1610612748
# 19      5   924,1610612764
# 20      5  1533,1610612751
# 21      5   193,1610612749
# 22      5   324,1610612750
# 23      5  2541,1610612742
# 24      5   952,1610612738
# 25      5  1498,1610612757
# 26      5   213,1610612761
# 27      5  1609,1610612761
# 28      5   717,1610612757
# 29      5  1506,1610612754
# ..    ...              ...
# 367     5   763,1610612762
# 368     5  2225,1610612759
# 369     5  1503,1610612753
# 370     5   145,1610612747
# 371     5   696,1610612748
# 372     5   969,1610612752
# 373     5  1762,1610612746
# 374     5  2239,1610612741
# 375     5  1607,1610612750
# 376     5  2211,1610612744
# 377     5   238,1610612755
# 378     5  1731,1610612764
# 379     5  2199,1610612741
# 380     5   452,1610612738
# 381     5  1713,1610612761
# 382     5  2428,1610612743
# 383     5   958,1610612760
# 384     5   124,1610612758
# 385     5  2209,1610612760
# 386     5  1735,1610612748
# 387     5   702,1610612761
# 388     5  1887,1610612750
# 389     5  1005,1610612742
# 390     5   962,1610612738
# 391     5  1917,1610612746
# 392     5   445,1610612763
# 393     5  2397,1610612745
# 394     5  2216,1610612757
# 395     5  1442,1610612765
# 396     5   980,1610612739
#
# [397 rows x 66 columns]

# %%
df_2002['PTS'].plot.hist(bins=40)

# %%
df_2002.columns[1:]
#pts_2016 = df_2016.as_matrix(columns=df_2016.columns[27:])
#x = pts_2016 #The array needs to be larger than 20, just an example
#mx = ma.masked_array(x)
#z,pval = mstats.normaltest(mx)

#if(pval < 0.055):
#   print("Not normal distribution")
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK',
#        'TD3_RANK', 'CFID', 'CFPARAMS'],
#       dtype='object')

# %%
z,pval = stats.normaltest(df_2002['PTS'])
print(z, pval)
if(pval < 0.05):
    print('PTS Is not from a Normal Dist')
else:
    print('PTS Is likley from a Normal Dist')

size = df_2002['PTS'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2002['PTS'])
stat, kpval = kstest(df_2002['PTS'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Gamma Dist')
else:
    print('PTS Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2002['PTS'])
stat, kpval = kstest(df_2002['PTS'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Log norm Dist')
else:
    print('PTS Is likley from a Log norm Dist')
# Out:
# 71.6760852477 2.7273184236e-16
# PTS Is not from a Normal Dist
# 0.0270913564433 0.932697392403
# PTS Is likley from a Gamma Dist
# 0.0323047123019 0.801751183059
# PTS Is likley from a Log norm Dist

# %%
df_2002['BLK'].plot.hist(bins=10)

# %%
z,pval = stats.normaltest(df_2002['BLK'])
print(z, pval)
if(pval < 0.05):
    print('BLK Is not from a Normal Dist')
else:
    print('BLK Is likley from a Normal Dist')
    
size = df_2002['BLK'].size
x = scipy.arange(size)
param = stats.expon.fit(df_2002['BLK'])
stat, kpval = kstest(df_2002['BLK'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Exponen Dist')
else:
    print('BLK Is likley from a Exponen Dist')
param = stats.gamma.fit(df_2002['BLK'])
stat, kpval = kstest(df_2002['BLK'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Gamma Dist')
else:
    print('BLK Is likley from a Gamma Dist')
param = stats.lognorm.fit(df_2002['BLK'])
stat, kpval = kstest(df_2002['BLK'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Log norm Dist')
else:
    print('BLK Is likley from a Log norm Dist')
param = stats.chi2.fit(df_2002['BLK'])
stat, kpval = kstest(df_2002['BLK'], 'chi2', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Chisq Dist')
else:
    print('BLK Is likley from a Chisq Dist')
# Out:
# 205.810675027 2.03600930925e-45
# BLK Is not from a Normal Dist
# 0.104550968605 0.000312086240179
# BLK Is not from a Exponen Dist
# 0.19366105862 1.6187051699e-13
# BLK Is not from a Gamma Dist
# 0.113999065921 5.97114186207e-05
# BLK Is not from a Log norm Dist
# 0.252705077379 0.0
# BLK Is not from a Chisq Dist

# %%
df_2002['STL'].plot.hist(bins=15)

# %%
z,pval = stats.normaltest(df_2002['STL'])
print(z, pval)
if(pval < 0.05):
    print('STL Is not from a Normal Dist')
else:
    print('STL Is likley from a Normal Dist')
    
size = df_2002['STL'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2002['STL'])
stat, kpval = kstest(df_2002['STL'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Gamma Dist')
else:
    print('STL Is likley from a Gamma Dist')

param = stats.expon.fit(df_2002['STL'])
stat, kpval = kstest(df_2002['STL'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Exponen Dist')
else:
    print('STL Is likley from a Exponen Dist')

param = stats.lognorm.fit(df_2002['STL'])
stat, kpval = kstest(df_2002['STL'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Log norm Dist')
else:
    print('STL Is likley from a Log norm Dist')
# Out:
# 62.9451409413 2.14603259165e-14
# STL Is not from a Normal Dist
# 0.0678371255451 0.0494044673637
# STL Is not from a Gamma Dist
# 0.197901517409 4.21884749358e-14
# STL Is not from a Exponen Dist
# 0.0769315146285 0.0172311240421
# STL Is not from a Log norm Dist

# %%
df_2002['TOV'].plot.hist(bins=12)

# %%
z,pval = stats.normaltest(df_2002['TOV'])
print(z, pval)
if(pval < 0.05):
    print('TOV Is not from a Normal Dist')
else:
    print('TOV Is likley from a Normal Dist')
    
size = df_2002['TOV'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2002['TOV'])
stat, kpval = kstest(df_2002['TOV'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Gamma Dist')
else:
    print('TOV Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2002['TOV'])
stat, kpval = kstest(df_2002['TOV'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Log norm Dist')
else:
    print('TOV Is likley from a Log norm Dist')
# Out:
# 50.8555529794 9.05434385229e-12
# TOV Is not from a Normal Dist
# 0.0803443121535 0.0112156700944
# TOV Is not from a Gamma Dist
# 0.0689474101179 0.0437516443244
# TOV Is not from a Log norm Dist

# %%
df_2002['AST'].plot.hist(bins=20)

# %%
z,pval = stats.normaltest(df_2002['AST'])
print(z, pval)
if(pval < 0.05):
    print('AST Is not from a Normal Dist')
else:
    print('AST Is likley from a Normal Dist')

size = df_2002['AST'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2002['AST'])
stat, kpval = kstest(df_2002['AST'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Gamma Dist')
else:
    print('AST Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2002['AST'])
stat, kpval = kstest(df_2002['AST'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Log norm Dist')
else:
    print('AST Is likley from a Log norm Dist')
# Out:
# 114.777578188 1.19224517442e-25
# AST Is not from a Normal Dist
# 0.0712319956209 0.0338623940386
# AST Is not from a Gamma Dist
# 0.052784507099 0.211307597546
# AST Is likley from a Log norm Dist

# %%
df_2002['REB'].plot.hist(bins=25)

# %%
z,pval = stats.normaltest(df_2002['REB'])
print(z, pval)
if(pval < 0.05):
    print('REB Is not from a Normal Dist')
else:
    print('REB Is likley from a Normal Dist')
    
size = df_2002['REB'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2002['REB'])
stat, kpval = kstest(df_2002['REB'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Gamma Dist')
else:
    print('REB Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2002['REB'])
stat, kpval = kstest(df_2002['REB'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Log norm Dist')
else:
    print('REB Is likley from a Log norm Dist')
# Out:
# 85.3498243426 2.9276632978e-19
# REB Is not from a Normal Dist
# 0.0256905957038 0.955832797046
# REB Is likley from a Gamma Dist
# 0.0346523966154 0.727078822088
# REB Is likley from a Log norm Dist
