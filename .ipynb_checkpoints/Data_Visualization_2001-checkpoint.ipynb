# %%
# Imports - these are all the imports needed for the assignment
# %matplotlib inline
from scipy import stats
import numpy.ma as ma
from scipy.stats import kstest, normaltest

import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1a) Load the nba csv files

# YOUR CODE HERE
df_2001 = pd.read_csv('clean_players_2001.csv')

# %%
df_2001
# Out:
#      Unnamed: 0  PLAYER_ID          PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0             0       2062          A.J. Guyton  1610612741               CHI
# 1             1        243          Aaron McKie  1610612755               PHI
# 2             2       1425       Aaron Williams  1610612751               NJN
# 3             3       1502         Adonal Foyle  1610612744               GSW
# 4             4       1559       Adrian Griffin  1610612742               DAL
# 5             5       1733        Al Harrington  1610612754               IND
# 6             6        673       Alan Henderson  1610612737               ATL
# 7             7        275        Allan Houston  1610612752               NYK
# 8             8        947        Allen Iverson  1610612755               PHI
# 9             9        297      Alonzo Mourning  1610612748               MIA
# 10           10       2228           Alton Ford  1610612756               PHX
# 11           11       2264          Alvin Jones  1610612755               PHI
# 12           12       1541       Alvin Williams  1610612761               TOR
# 13           13       1043       Amal McCaskill  1610612759               SAS
# 14           14       1889         Andre Miller  1610612739               CLE
# 15           15       1905     Andrei Kirilenko  1610612762               UTA
# 16           16        692      Andrew DeClercq  1610612753               ORL
# 17           17        358    Anfernee Hardaway  1610612756               PHX
# 18           18       1738           Ansu Sesay  1610612760               SEA
# 19           19       1712       Antawn Jamison  1610612744               GSW
# 20           20       1853       Anthony Carter  1610612748               MIA
# 21           21       1533      Anthony Johnson  1610612751               NJN
# 22           22        193        Anthony Mason  1610612749               MIL
# 23           23        324       Anthony Peeler  1610612750               MIN
# 24           24        952       Antoine Walker  1610612738               BOS
# 25           25       1498      Antonio Daniels  1610612759               SAS
# 26           26        213        Antonio Davis  1610612761               TOR
# 27           28        686      Antonio McDyess  1610612743               DEN
# 28           29       2238       Antonis Fotsis  1610612763               MEM
# 29           30       1609             Art Long  1610612760               SEA
# ..          ...        ...                  ...         ...               ...
# 381         409        696          Travis Best  1610612741               CHI
# 382         410        969        Travis Knight  1610612752               NYK
# 383         411       1762     Tremaine Fowlkes  1610612746               LAC
# 384         412       2239      Trenton Hassell  1610612741               CHI
# 385         413       1607          Troy Hudson  1610612753               ORL
# 386         414       2211          Troy Murphy  1610612744               GSW
# 387         415        238          Tyrone Hill  1610612739               CLE
# 388         416       1838         Tyrone Nesby  1610612764               WAS
# 389         417       1731           Tyronn Lue  1610612764               WAS
# 390         418       2199       Tyson Chandler  1610612741               CHI
# 391         419       2349     Victor Alexander  1610612765               DET
# 392         420        452            Vin Baker  1610612760               SEA
# 393         421       1713         Vince Carter  1610612761               TOR
# 394         423        958     Vitaly Potapenko  1610612738               BOS
# 395         424        124          Vlade Divac  1610612758               SAC
# 396         425       2209  Vladimir Radmanovic  1610612760               SEA
# 397         426       1735    Vladimir Stepania  1610612748               MIA
# 398         427       1907    Vonteego Cummings  1610612755               PHI
# 399         428        702        Voshon Lenard  1610612743               DEN
# 400         429       1887     Wally Szczerbiak  1610612750               MIN
# 401         430       1005        Walt Williams  1610612745               HOU
# 402         431        962       Walter McCarty  1610612738               BOS
# 403         432       1917         Wang Zhi-zhi  1610612742               DAL
# 404         433        445        Wesley Person  1610612739               CLE
# 405         434       2226         Will Solomon  1610612763               MEM
# 406         435       1895        William Avery  1610612750               MIN
# 407         436       2216        Zach Randolph  1610612757               POR
# 408         437       1442       Zeljko Rebraca  1610612765               DET
# 409         438       1985      Zendon Hamilton  1610612743               DEN
# 410         439        980   Zydrunas Ilgauskas  1610612739               CLE
#
#       AGE  GP   W   L  W_PCT       ...         BLKA_RANK  PF_RANK  PFD_RANK  \
# 0
# 397     5  1735,1610612748
# 398     5  1907,1610612755
# 399     5   702,1610612743
# 400     5  1887,1610612750
# 401     5  1005,1610612745
# 402     5   962,1610612738
# 403     5  1917,1610612742
# 404     5   445,1610612739
# 405     5  2226,1610612763
# 406     5  1895,1610612750
# 407     5  2216,1610612757
# 408     5  1442,1610612765
# 409     5  1985,1610612743
# 410     5   980,1610612739
#
# [411 rows x 66 columns]

# %%
df_2001['PTS'].plot.hist(bins=40)

# %%
df_2001.columns[1:]
#pts_2016 = df_2016.as_matrix(columns=df_2016.columns[27:])
#x = pts_2016 #The array needs to be larger than 20, just an example
#mx = ma.masked_array(x)
#z,pval = mstats.normaltest(mx)

#if(pval < 0.055):
#   print("Not normal distribution")
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION', 'AGE', 'GP',
#        'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK', 'DD2_RANK',
#        'TD3_RANK', 'CFID', 'CFPARAMS'],
#       dtype='object')

# %%
z,pval = mstats.normaltest(df_2001['PTS'])
print(z, pval)
if(pval < 0.05):
    print('PTS Is not from a Normal Dist')
else:
    print('PTS Is likley from a Normal Dist')

size = df_2001['PTS'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2001['PTS'])
stat, kpval = kstest(df_2001['PTS'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Gamma Dist')
else:
    print('PTS Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2001['PTS'])
stat, kpval = kstest(df_2001['PTS'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('PTS Is not from a Log norm Dist')
else:
    print('PTS Is likley from a Log norm Dist')
# Out:
# 67.7457904533 1.94620469982e-15
# PTS Is not from a Normal Dist
# 0.0355255923411 0.677372942263
# PTS Is likley from a Gamma Dist
# 0.0467359332907 0.321945083205
# PTS Is likley from a Log norm Dist

# %%
df_2001['BLK'].plot.hist(bins=10)

# %%
z,pval = mstats.normaltest(df_2001['BLK'])
print(z, pval)
if(pval < 0.05):
    print('BLK Is not from a Normal Dist')
else:
    print('BLK Is likley from a Normal Dist')
    
size = df_2001['BLK'].size
x = scipy.arange(size)
param = stats.expon.fit(df_2001['BLK'])
stat, kpval = kstest(df_2001['BLK'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Exponen Dist')
else:
    print('BLK Is likley from a Exponen Dist')
param = stats.gamma.fit(df_2001['BLK'])
stat, kpval = kstest(df_2001['BLK'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Gamma Dist')
else:
    print('BLK Is likley from a Gamma Dist')
param = stats.lognorm.fit(df_2001['BLK'])
stat, kpval = kstest(df_2001['BLK'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Log norm Dist')
else:
    print('BLK Is likley from a Log norm Dist')
param = stats.chi2.fit(df_2001['BLK'])
stat, kpval = kstest(df_2001['BLK'], 'chi2', param)
print(stat, kpval)
if(kpval < 0.05):
    print('BLK Is not from a Chisq Dist')
else:
    print('BLK Is likley from a Chisq Dist')
# Out:
# 199.55677069 4.64299088839e-44
# BLK Is not from a Normal Dist
# 0.108978233906 0.000104884092679
# BLK Is not from a Exponen Dist
# 0.25635625764 0.0
# BLK Is not from a Gamma Dist
# 0.110148315517 8.47995142563e-05
# BLK Is not from a Log norm Dist
# 0.454780007736 0.0
# BLK Is not from a Chisq Dist

# %%
df_2001['STL'].plot.hist(bins=15)

# %%
z,pval = mstats.normaltest(df_2001['STL'])
print(z, pval)
if(pval < 0.05):
    print('STL Is not from a Normal Dist')
else:
    print('STL Is likley from a Normal Dist')
    
size = df_2001['STL'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2001['STL'])
stat, kpval = kstest(df_2001['STL'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Gamma Dist')
else:
    print('STL Is likley from a Gamma Dist')

param = stats.expon.fit(df_2001['STL'])
stat, kpval = kstest(df_2001['STL'], 'expon', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Exponen Dist')
else:
    print('STL Is likley from a Exponen Dist')

param = stats.lognorm.fit(df_2001['STL'])
stat, kpval = kstest(df_2001['STL'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('STL Is not from a Log norm Dist')
else:
    print('STL Is likley from a Log norm Dist')
# Out:
# 73.180874213 1.28521289466e-16
# STL Is not from a Normal Dist
# 0.0843981145028 0.0053830804275
# STL Is not from a Gamma Dist
# 0.202566734755 2.88657986403e-15
# STL Is not from a Exponen Dist
# 0.0891673961629 0.00271203637575
# STL Is not from a Log norm Dist

# %%
df_2001['TOV'].plot.hist(bins=12)

# %%
z,pval = mstats.normaltest(df_2001['TOV'])
print(z, pval)
if(pval < 0.05):
    print('TOV Is not from a Normal Dist')
else:
    print('TOV Is likley from a Normal Dist')
    
size = df_2001['TOV'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2001['TOV'])
stat, kpval = kstest(df_2001['TOV'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Gamma Dist')
else:
    print('TOV Is likley from a Gamma Dist')
    
param = stats.lognorm.fit(df_2001['TOV'])
stat, kpval = kstest(df_2001['TOV'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('TOV Is not from a Log norm Dist')
else:
    print('TOV Is likley from a Log norm Dist')
# Out:
# 51.1642847844 7.75919602427e-12
# TOV Is not from a Normal Dist
# 0.0631303430067 0.0723568749903
# TOV Is likley from a Gamma Dist
# 0.0587259817946 0.112867501573
# TOV Is likley from a Log norm Dist

# %%
df_2001['AST'].plot.hist(bins=20)

# %%
z,pval = mstats.normaltest(df_2001['AST'])
print(z, pval)
if(pval < 0.05):
    print('AST Is not from a Normal Dist')
else:
    print('AST Is likley from a Normal Dist')

size = df_2001['AST'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2001['AST'])
stat, kpval = kstest(df_2001['AST'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Gamma Dist')
else:
    print('AST Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2001['AST'])
stat, kpval = kstest(df_2001['AST'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('AST Is not from a Log norm Dist')
else:
    print('AST Is likley from a Log norm Dist')
# Out:
# 151.347027347 1.36587383388e-33
# AST Is not from a Normal Dist
# 0.149841813416 1.60663671256e-08
# AST Is not from a Gamma Dist
# 0.0579050302348 0.122186096957
# AST Is likley from a Log norm Dist

# %%
df_2001['REB'].plot.hist(bins=25)

# %%
z,pval = mstats.normaltest(df_2001['REB'])
print(z, pval)
if(pval < 0.05):
    print('REB Is not from a Normal Dist')
else:
    print('REB Is likley from a Normal Dist')
    
size = df_2001['REB'].size
x = scipy.arange(size)
param = stats.gamma.fit(df_2001['REB'])
stat, kpval = kstest(df_2001['REB'], 'gamma', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Gamma Dist')
else:
    print('REB Is likley from a Gamma Dist')

param = stats.lognorm.fit(df_2001['REB'])
stat, kpval = kstest(df_2001['REB'], 'lognorm', param)
print(stat, kpval)
if(kpval < 0.05):
    print('REB Is not from a Log norm Dist')
else:
    print('REB Is likley from a Log norm Dist')
# Out:
# 77.3304687122 1.61399460106e-17
# REB Is not from a Normal Dist
# 0.0409301298192 0.491157645515
# REB Is likley from a Gamma Dist
# 0.045874500951 0.343972101427
# REB Is likley from a Log norm Dist
